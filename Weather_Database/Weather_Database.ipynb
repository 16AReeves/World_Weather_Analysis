# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import citipy

import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 732

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aqtobe
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | portland
# Processing Record 4 of Set 1 | wonthaggi
# Processing Record 5 of Set 1 | westport
# Processing Record 6 of Set 1 | key largo
# Processing Record 7 of Set 1 | khatanga
# Processing Record 8 of Set 1 | ancud
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | vestmannaeyjar
# Processing Record 11 of Set 1 | aguimes
# Processing Record 12 of Set 1 | labuhan
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | baghdad
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | dawson
# Processing Record 22 of Set 1 | arraial do cabo
# Processing Record 23 of Set 1 | kenai
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | krasnyy oktyabr
# Processing Record 26 of Set 1 | anori
# Processing Record 27 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | upernavik
# Processing Record 30 of Set 1 | jamestown
# Processing Record 31 of Set 1 | lompoc
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | bonavista
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | stepantsevo
# Processing Record 36 of Set 1 | boda
# Processing Record 37 of Set 1 | hebertville
# City not found. Skipping...
# Processing Record 38 of Set 1 | luba
# Processing Record 39 of Set 1 | albany
# Processing Record 40 of Set 1 | castro
# Processing Record 41 of Set 1 | puerto narino
# Processing Record 42 of Set 1 | katsuura
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | goderich
# Processing Record 45 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | bredasdorp
# Processing Record 48 of Set 1 | georgetown
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | rorvik
# Processing Record 1 of Set 2 | viedma
# Processing Record 2 of Set 2 | anda
# Processing Record 3 of Set 2 | ahipara
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | lavrentiya
# Processing Record 6 of Set 2 | kodiak
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | provideniya
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 11 of Set 2 | ofaqim
# Processing Record 12 of Set 2 | praia da vitoria
# Processing Record 13 of Set 2 | saldanha
# Processing Record 14 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 2 | tekirdag
# Processing Record 16 of Set 2 | brae
# Processing Record 17 of Set 2 | dharchula
# Processing Record 18 of Set 2 | richards bay
# Processing Record 19 of Set 2 | busselton
# Processing Record 20 of Set 2 | naze
# Processing Record 21 of Set 2 | havre de grace
# Processing Record 22 of Set 2 | bethel
# Processing Record 23 of Set 2 | vaini
# Processing Record 24 of Set 2 | olomouc
# Processing Record 25 of Set 2 | kaitangata
# Processing Record 26 of Set 2 | los llanos de aridane
# Processing Record 27 of Set 2 | kavieng
# Processing Record 28 of Set 2 | atuona
# Processing Record 29 of Set 2 | san rafael
# Processing Record 30 of Set 2 | clyde river
# Processing Record 31 of Set 2 | deputatskiy
# Processing Record 32 of Set 2 | nantucket
# Processing Record 33 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 2 | athabasca
# Processing Record 35 of Set 2 | airai
# Processing Record 36 of Set 2 | san cristobal
# Processing Record 37 of Set 2 | ponta do sol
# Processing Record 38 of Set 2 | longyearbyen
# Processing Record 39 of Set 2 | saint george
# Processing Record 40 of Set 2 | new norfolk
# Processing Record 41 of Set 2 | humaita
# Processing Record 42 of Set 2 | vila franca do campo
# Processing Record 43 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 44 of Set 2 | roma
# Processing Record 45 of Set 2 | prince rupert
# Processing Record 46 of Set 2 | laramie
# Processing Record 47 of Set 2 | cherrapunji
# Processing Record 48 of Set 2 | adrar
# Processing Record 49 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 2 | cativa
# Processing Record 1 of Set 3 | taitung
# Processing Record 2 of Set 3 | ostrovnoy
# Processing Record 3 of Set 3 | bontang
# Processing Record 4 of Set 3 | buala
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | taltal
# Processing Record 7 of Set 3 | san vicente
# Processing Record 8 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 3 | severo-kurilsk
# Processing Record 10 of Set 3 | flinders
# Processing Record 11 of Set 3 | lampazos de naranjo
# Processing Record 12 of Set 3 | port lincoln
# Processing Record 13 of Set 3 | ilulissat
# Processing Record 14 of Set 3 | venado tuerto
# Processing Record 15 of Set 3 | samarai
# Processing Record 16 of Set 3 | sao felix do xingu
# Processing Record 17 of Set 3 | sokolow podlaski
# Processing Record 18 of Set 3 | savda
# Processing Record 19 of Set 3 | nanortalik
# Processing Record 20 of Set 3 | zapolyarnyy
# Processing Record 21 of Set 3 | dikson
# Processing Record 22 of Set 3 | port macquarie
# Processing Record 23 of Set 3 | mamonovo
# Processing Record 24 of Set 3 | grand-santi
# Processing Record 25 of Set 3 | cidreira
# Processing Record 26 of Set 3 | tasiilaq
# Processing Record 27 of Set 3 | port elizabeth
# Processing Record 28 of Set 3 | saint-philippe
# Processing Record 29 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 3 | san carlos de bariloche
# Processing Record 31 of Set 3 | caucaia
# Processing Record 32 of Set 3 | raymondville
# Processing Record 33 of Set 3 | marabba
# Processing Record 34 of Set 3 | nouadhibou
# Processing Record 35 of Set 3 | geraldton
# Processing Record 36 of Set 3 | faya
# Processing Record 37 of Set 3 | morelia
# Processing Record 38 of Set 3 | trogir
# Processing Record 39 of Set 3 | nikolskoye
# Processing Record 40 of Set 3 | pevek
# Processing Record 41 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 3 | moorhead
# Processing Record 43 of Set 3 | kizema
# Processing Record 44 of Set 3 | san luis
# Processing Record 45 of Set 3 | grindavik
# Processing Record 46 of Set 3 | mahebourg
# Processing Record 47 of Set 3 | berlevag
# Processing Record 48 of Set 3 | meulaboh
# Processing Record 49 of Set 3 | anadyr
# Processing Record 50 of Set 3 | coracao de jesus
# Processing Record 1 of Set 4 | maracaju
# Processing Record 2 of Set 4 | port alfred
# Processing Record 3 of Set 4 | hithadhoo
# Processing Record 4 of Set 4 | twin falls
# Processing Record 5 of Set 4 | vung tau
# Processing Record 6 of Set 4 | khanpur
# Processing Record 7 of Set 4 | isla mujeres
# Processing Record 8 of Set 4 | dakar
# Processing Record 9 of Set 4 | klaksvik
# Processing Record 10 of Set 4 | cabras
# Processing Record 11 of Set 4 | ribeira grande
# Processing Record 12 of Set 4 | sao filipe
# Processing Record 13 of Set 4 | mahanje
# Processing Record 14 of Set 4 | zhangye
# Processing Record 15 of Set 4 | doctor juan leon mallorquin
# Processing Record 16 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 4 | boguchany
# Processing Record 18 of Set 4 | itatuba
# Processing Record 19 of Set 4 | leningradskiy
# Processing Record 20 of Set 4 | caravelas
# Processing Record 21 of Set 4 | adre
# Processing Record 22 of Set 4 | chifeng
# Processing Record 23 of Set 4 | kushmurun
# Processing Record 24 of Set 4 | rapid valley
# Processing Record 25 of Set 4 | norman wells
# Processing Record 26 of Set 4 | hunchun
# Processing Record 27 of Set 4 | souillac
# Processing Record 28 of Set 4 | byron bay
# Processing Record 29 of Set 4 | pont-a-mousson
# Processing Record 30 of Set 4 | tambura
# Processing Record 31 of Set 4 | hasaki
# Processing Record 32 of Set 4 | thompson
# Processing Record 33 of Set 4 | raseiniai
# Processing Record 34 of Set 4 | lagoa
# Processing Record 35 of Set 4 | salalah
# Processing Record 36 of Set 4 | tuktoyaktuk
# Processing Record 37 of Set 4 | resistencia
# Processing Record 38 of Set 4 | chulman
# Processing Record 39 of Set 4 | alofi
# Processing Record 40 of Set 4 | itaquyry
# Processing Record 41 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 4 | guerrero negro
# Processing Record 43 of Set 4 | nicoya
# Processing Record 44 of Set 4 | eydhafushi
# Processing Record 45 of Set 4 | chazuta
# Processing Record 46 of Set 4 | batagay-alyta
# Processing Record 47 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 48 of Set 4 | katherine
# Processing Record 49 of Set 4 | port hardy
# Processing Record 50 of Set 4 | kitsuki
# Processing Record 1 of Set 5 | horadiz
# Processing Record 2 of Set 5 | valdivia
# Processing Record 3 of Set 5 | mago
# Processing Record 4 of Set 5 | laguna
# Processing Record 5 of Set 5 | trincomalee
# Processing Record 6 of Set 5 | bengkulu
# Processing Record 7 of Set 5 | kurumkan
# Processing Record 8 of Set 5 | tabou
# Processing Record 9 of Set 5 | cherskiy
# Processing Record 10 of Set 5 | collie
# Processing Record 11 of Set 5 | karpathos
# Processing Record 12 of Set 5 | anloga
# Processing Record 13 of Set 5 | rawson
# Processing Record 14 of Set 5 | matara
# Processing Record 15 of Set 5 | sisimiut
# Processing Record 16 of Set 5 | olafsvik
# Processing Record 17 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 5 | manihari
# Processing Record 19 of Set 5 | atar
# Processing Record 20 of Set 5 | clarence town
# Processing Record 21 of Set 5 | bani
# Processing Record 22 of Set 5 | valle de allende
# Processing Record 23 of Set 5 | krasnyy tkach
# Processing Record 24 of Set 5 | waipawa
# Processing Record 25 of Set 5 | tura
# Processing Record 26 of Set 5 | bilibino
# Processing Record 27 of Set 5 | aklavik
# Processing Record 28 of Set 5 | wilmington
# Processing Record 29 of Set 5 | welkom
# Processing Record 30 of Set 5 | helong
# Processing Record 31 of Set 5 | mae sai
# Processing Record 32 of Set 5 | komsomolskiy
# Processing Record 33 of Set 5 | chokurdakh
# Processing Record 34 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 5 | kanakapura
# Processing Record 36 of Set 5 | sri aman
# Processing Record 37 of Set 5 | nishihara
# Processing Record 38 of Set 5 | carnarvon
# Processing Record 39 of Set 5 | buin
# Processing Record 40 of Set 5 | kargat
# Processing Record 41 of Set 5 | vao
# Processing Record 42 of Set 5 | biak
# Processing Record 43 of Set 5 | qaanaaq
# Processing Record 44 of Set 5 | tateyama
# Processing Record 45 of Set 5 | buraydah
# Processing Record 46 of Set 5 | weinan
# Processing Record 47 of Set 5 | codrington
# Processing Record 48 of Set 5 | la ronge
# Processing Record 49 of Set 5 | galle
# Processing Record 50 of Set 5 | hebi
# Processing Record 1 of Set 6 | walvis bay
# Processing Record 2 of Set 6 | aykhal
# Processing Record 3 of Set 6 | raudeberg
# Processing Record 4 of Set 6 | daru
# Processing Record 5 of Set 6 | nalut
# Processing Record 6 of Set 6 | tazovskiy
# Processing Record 7 of Set 6 | paradwip
# City not found. Skipping...
# Processing Record 8 of Set 6 | kita
# Processing Record 9 of Set 6 | barrow
# Processing Record 10 of Set 6 | sattahip
# Processing Record 11 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 6 | narsaq
# Processing Record 13 of Set 6 | coahuayana
# Processing Record 14 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 6 | ust-kuyga
# Processing Record 16 of Set 6 | valle hermoso
# Processing Record 17 of Set 6 | lodja
# Processing Record 18 of Set 6 | beberibe
# Processing Record 19 of Set 6 | saint-joseph
# Processing Record 20 of Set 6 | gornopravdinsk
# Processing Record 21 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 22 of Set 6 | chuy
# Processing Record 23 of Set 6 | sitka
# Processing Record 24 of Set 6 | lisieux
# Processing Record 25 of Set 6 | ishigaki
# Processing Record 26 of Set 6 | santa rosa
# Processing Record 27 of Set 6 | wejherowo
# Processing Record 28 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 6 | manakara
# Processing Record 30 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 31 of Set 6 | hinton
# Processing Record 32 of Set 6 | puerto ayacucho
# Processing Record 33 of Set 6 | sola
# Processing Record 34 of Set 6 | lubang
# Processing Record 35 of Set 6 | bubaque
# Processing Record 36 of Set 6 | marataizes
# Processing Record 37 of Set 6 | santa fe
# Processing Record 38 of Set 6 | axim
# Processing Record 39 of Set 6 | guane
# Processing Record 40 of Set 6 | comodoro rivadavia
# Processing Record 41 of Set 6 | havre-saint-pierre
# Processing Record 42 of Set 6 | valentin gomez farias
# Processing Record 43 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 44 of Set 6 | bobo dioulasso
# Processing Record 45 of Set 6 | olinda
# Processing Record 46 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 47 of Set 6 | hollins
# Processing Record 48 of Set 6 | namibe
# Processing Record 49 of Set 6 | dir
# Processing Record 50 of Set 6 | oruro
# Processing Record 1 of Set 7 | bratsk
# Processing Record 2 of Set 7 | kuytun
# Processing Record 3 of Set 7 | puerto colombia
# Processing Record 4 of Set 7 | college
# Processing Record 5 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 6 of Set 7 | purgstall
# Processing Record 7 of Set 7 | yar-sale
# Processing Record 8 of Set 7 | talnakh
# Processing Record 9 of Set 7 | darhan
# Processing Record 10 of Set 7 | timizart
# Processing Record 11 of Set 7 | pangnirtung
# Processing Record 12 of Set 7 | mundo nuevo
# Processing Record 13 of Set 7 | maragogi
# Processing Record 14 of Set 7 | ocos
# Processing Record 15 of Set 7 | blythe
# Processing Record 16 of Set 7 | lorengau
# Processing Record 17 of Set 7 | mackay
# Processing Record 18 of Set 7 | san patricio
# Processing Record 19 of Set 7 | necochea
# Processing Record 20 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 22 of Set 7 | dawson creek
# Processing Record 23 of Set 7 | kilindoni
# Processing Record 24 of Set 7 | den helder
# Processing Record 25 of Set 7 | luderitz
# Processing Record 26 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 27 of Set 7 | saskylakh
# Processing Record 28 of Set 7 | niquelandia
# Processing Record 29 of Set 7 | lucapa
# Processing Record 30 of Set 7 | kota
# Processing Record 31 of Set 7 | puerto escondido
# Processing Record 32 of Set 7 | banjar
# Processing Record 33 of Set 7 | nowy targ
# Processing Record 34 of Set 7 | shebunino
# Processing Record 35 of Set 7 | vostok
# Processing Record 36 of Set 7 | halifax
# Processing Record 37 of Set 7 | atasu
# Processing Record 38 of Set 7 | odweyne
# Processing Record 39 of Set 7 | srednekolymsk
# Processing Record 40 of Set 7 | cololaca
# Processing Record 41 of Set 7 | mosquera
# Processing Record 42 of Set 7 | karatau
# Processing Record 43 of Set 7 | soyo
# Processing Record 44 of Set 7 | langres
# Processing Record 45 of Set 7 | zhuhai
# Processing Record 46 of Set 7 | vila velha
# Processing Record 47 of Set 7 | atherton
# Processing Record 48 of Set 7 | marzuq
# Processing Record 49 of Set 7 | boca do acre
# Processing Record 50 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 8 | bandarbeyla
# Processing Record 2 of Set 8 | linjiang
# Processing Record 3 of Set 8 | ixtapa
# Processing Record 4 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 8 | coquimbo
# Processing Record 6 of Set 8 | matai
# Processing Record 7 of Set 8 | la llanada
# Processing Record 8 of Set 8 | aksu
# Processing Record 9 of Set 8 | vardo
# Processing Record 10 of Set 8 | kawalu
# Processing Record 11 of Set 8 | nome
# Processing Record 12 of Set 8 | mulanje
# Processing Record 13 of Set 8 | nyurba
# Processing Record 14 of Set 8 | iqaluit
# Processing Record 15 of Set 8 | diego de almagro
# Processing Record 16 of Set 8 | kapoeta
# Processing Record 17 of Set 8 | kilemary
# Processing Record 18 of Set 8 | saint combs
# City not found. Skipping...
# Processing Record 19 of Set 8 | seydi
# Processing Record 20 of Set 8 | visnes
# Processing Record 21 of Set 8 | sinnar
# Processing Record 22 of Set 8 | shimoda
# Processing Record 23 of Set 8 | aberdeen
# Processing Record 24 of Set 8 | kiama
# Processing Record 25 of Set 8 | eyl
# Processing Record 26 of Set 8 | tommot
# Processing Record 27 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 8 | manaia
# Processing Record 29 of Set 8 | arawa
# Processing Record 30 of Set 8 | te anau
# Processing Record 31 of Set 8 | kloulklubed
# Processing Record 32 of Set 8 | lensk
# Processing Record 33 of Set 8 | touros
# Processing Record 34 of Set 8 | roald
# Processing Record 35 of Set 8 | torbay
# Processing Record 36 of Set 8 | isangel
# Processing Record 37 of Set 8 | alekseyevsk
# Processing Record 38 of Set 8 | inhambane
# Processing Record 39 of Set 8 | dunedin
# Processing Record 40 of Set 8 | umm kaddadah
# Processing Record 41 of Set 8 | coracora
# Processing Record 42 of Set 8 | harper
# Processing Record 43 of Set 8 | pontianak
# Processing Record 44 of Set 8 | arroio grande
# Processing Record 45 of Set 8 | hanyang
# Processing Record 46 of Set 8 | esso
# Processing Record 47 of Set 8 | ketchikan
# Processing Record 48 of Set 8 | cabo san lucas
# Processing Record 49 of Set 8 | tanggul
# Processing Record 50 of Set 8 | narasannapeta
# Processing Record 1 of Set 9 | fortuna
# Processing Record 2 of Set 9 | pingliang
# Processing Record 3 of Set 9 | lakhipur
# Processing Record 4 of Set 9 | moose factory
# Processing Record 5 of Set 9 | nyrob
# Processing Record 6 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 9 | banff
# Processing Record 8 of Set 9 | billingham
# Processing Record 9 of Set 9 | victoria
# Processing Record 10 of Set 9 | mar del plata
# Processing Record 11 of Set 9 | belyy yar
# Processing Record 12 of Set 9 | yuma
# Processing Record 13 of Set 9 | hauterive
# Processing Record 14 of Set 9 | zhicheng
# Processing Record 15 of Set 9 | taoudenni
# Processing Record 16 of Set 9 | goundi
# Processing Record 17 of Set 9 | darya khan
# Processing Record 18 of Set 9 | bam
# Processing Record 19 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 9 | camalu
# Processing Record 21 of Set 9 | independence
# Processing Record 22 of Set 9 | maldonado
# Processing Record 23 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 24 of Set 9 | bojnice
# Processing Record 25 of Set 9 | bhuj
# Processing Record 26 of Set 9 | mugumu
# Processing Record 27 of Set 9 | beziers
# Processing Record 28 of Set 9 | sistranda
# Processing Record 29 of Set 9 | kiryas joel
# Processing Record 30 of Set 9 | casper
# Processing Record 31 of Set 9 | svetlogorsk
# Processing Record 32 of Set 9 | valparaiso
# Processing Record 33 of Set 9 | okha
# Processing Record 34 of Set 9 | sabha
# Processing Record 35 of Set 9 | high level
# Processing Record 36 of Set 9 | tibati
# Processing Record 37 of Set 9 | le passage
# Processing Record 38 of Set 9 | zaoyang
# Processing Record 39 of Set 9 | havelock
# Processing Record 40 of Set 9 | tevaitoa
# Processing Record 41 of Set 9 | la malbaie
# Processing Record 42 of Set 9 | medea
# Processing Record 43 of Set 9 | ponta delgada
# Processing Record 44 of Set 9 | yakima
# Processing Record 45 of Set 9 | moranbah
# Processing Record 46 of Set 9 | korce
# Processing Record 47 of Set 9 | nilagiri
# Processing Record 48 of Set 9 | abu dhabi
# Processing Record 49 of Set 9 | cockburn town
# Processing Record 50 of Set 9 | batemans bay
# Processing Record 1 of Set 10 | ndioum
# Processing Record 2 of Set 10 | lazaro cardenas
# Processing Record 3 of Set 10 | hamilton
# Processing Record 4 of Set 10 | beni suef
# Processing Record 5 of Set 10 | khomeynishahr
# City not found. Skipping...
# Processing Record 6 of Set 10 | kem
# Processing Record 7 of Set 10 | turayf
# Processing Record 8 of Set 10 | kikwit
# Processing Record 9 of Set 10 | zhigansk
# Processing Record 10 of Set 10 | cervo
# Processing Record 11 of Set 10 | da lat
# Processing Record 12 of Set 10 | baiyin
# Processing Record 13 of Set 10 | montrose
# Processing Record 14 of Set 10 | camacha
# Processing Record 15 of Set 10 | cabra
# Processing Record 16 of Set 10 | dehloran
# Processing Record 17 of Set 10 | asosa
# Processing Record 18 of Set 10 | rudbar
# Processing Record 19 of Set 10 | lincoln
# Processing Record 20 of Set 10 | eenhana
# Processing Record 21 of Set 10 | naryan-mar
# Processing Record 22 of Set 10 | bambous virieux
# Processing Record 23 of Set 10 | paysandu
# Processing Record 24 of Set 10 | puerto cabezas
# Processing Record 25 of Set 10 | niort
# Processing Record 26 of Set 10 | uvarovka
# Processing Record 27 of Set 10 | vega de alatorre
# Processing Record 28 of Set 10 | malakal
# Processing Record 29 of Set 10 | yeehaw junction
# City not found. Skipping...
# Processing Record 30 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 31 of Set 10 | wauconda
# Processing Record 32 of Set 10 | gwadar
# Processing Record 33 of Set 10 | beloha
# Processing Record 34 of Set 10 | binabalian
# Processing Record 35 of Set 10 | rio cuarto
# Processing Record 36 of Set 10 | jahrom
# City not found. Skipping...
# Processing Record 37 of Set 10 | hihya
# Processing Record 38 of Set 10 | ye
# City not found. Skipping...
# Processing Record 39 of Set 10 | mogadishu
# Processing Record 40 of Set 10 | najran
# Processing Record 41 of Set 10 | khani
# Processing Record 42 of Set 10 | hambantota
# Processing Record 43 of Set 10 | fonte boa
# Processing Record 44 of Set 10 | rancho palos verdes
# Processing Record 45 of Set 10 | petrovsk
# Processing Record 46 of Set 10 | safford
# Processing Record 47 of Set 10 | kruisfontein
# Processing Record 48 of Set 10 | broken hill
# Processing Record 49 of Set 10 | belawan
# Processing Record 50 of Set 10 | chichibu
# Processing Record 1 of Set 11 | alice springs
# Processing Record 2 of Set 11 | changji
# Processing Record 3 of Set 11 | mana
# Processing Record 4 of Set 11 | ampanihy
# Processing Record 5 of Set 11 | jumla
# Processing Record 6 of Set 11 | cotonou
# Processing Record 7 of Set 11 | kaiserslautern
# Processing Record 8 of Set 11 | pangoa
# Processing Record 9 of Set 11 | port blair
# Processing Record 10 of Set 11 | cap malheureux
# Processing Record 11 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 11 | taksimo
# Processing Record 13 of Set 11 | stromness
# Processing Record 14 of Set 11 | panguna
# Processing Record 15 of Set 11 | kamaishi
# Processing Record 16 of Set 11 | lodwar
# Processing Record 17 of Set 11 | yerofey pavlovich
# Processing Record 18 of Set 11 | bilma
# Processing Record 19 of Set 11 | townsville
# Processing Record 20 of Set 11 | lakhdenpokhya
# Processing Record 21 of Set 11 | todos santos
# Processing Record 22 of Set 11 | novo aripuana
# Processing Record 23 of Set 11 | mashhad
# Processing Record 24 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 25 of Set 11 | kavaratti
# Processing Record 26 of Set 11 | takahashi
# Processing Record 27 of Set 11 | eyrarbakki
# Processing Record 28 of Set 11 | husavik
# Processing Record 29 of Set 11 | east wenatchee bench
# Processing Record 30 of Set 11 | esperance
# Processing Record 31 of Set 11 | tecpan
# Processing Record 32 of Set 11 | bengkalis
# City not found. Skipping...
# Processing Record 33 of Set 11 | dwarka
# Processing Record 34 of Set 11 | tuatapere
# Processing Record 35 of Set 11 | aguas belas
# Processing Record 36 of Set 11 | katete
# Processing Record 37 of Set 11 | oranjemund
# Processing Record 38 of Set 11 | kudahuvadhoo
# Processing Record 39 of Set 11 | armidale
# Processing Record 40 of Set 11 | chicama
# Processing Record 41 of Set 11 | yima
# Processing Record 42 of Set 11 | catuday
# Processing Record 43 of Set 11 | coolum beach
# Processing Record 44 of Set 11 | nairn
# Processing Record 45 of Set 11 | port hedland
# Processing Record 46 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 11 | stornoway
# Processing Record 48 of Set 11 | sovetskiy
# Processing Record 49 of Set 11 | faanui
# Processing Record 50 of Set 11 | dukat
# Processing Record 1 of Set 12 | caraballeda
# Processing Record 2 of Set 12 | shahrud
# Processing Record 3 of Set 12 | oistins
# Processing Record 4 of Set 12 | chengde
# Processing Record 5 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 6 of Set 12 | severobaykalsk
# Processing Record 7 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 8 of Set 12 | fara in sabina
# Processing Record 9 of Set 12 | atyrau
# Processing Record 10 of Set 12 | campbell river
# Processing Record 11 of Set 12 | antalaha
# Processing Record 12 of Set 12 | hofn
# Processing Record 13 of Set 12 | port said
# Processing Record 14 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 12 | wajima
# Processing Record 16 of Set 12 | hede
# Processing Record 17 of Set 12 | mayo
# Processing Record 18 of Set 12 | phan thiet
# Processing Record 19 of Set 12 | mount isa
# Processing Record 20 of Set 12 | cayenne
# Processing Record 21 of Set 12 | dinar
# Processing Record 22 of Set 12 | kolokani
# Processing Record 23 of Set 12 | marieville
# Processing Record 24 of Set 12 | jishou
# Processing Record 25 of Set 12 | bad aussee
# Processing Record 26 of Set 12 | kahului
# Processing Record 27 of Set 12 | cadillac
# Processing Record 28 of Set 12 | thinadhoo
# Processing Record 29 of Set 12 | pitimbu
# Processing Record 30 of Set 12 | parfenyevo
# Processing Record 31 of Set 12 | shingu
# Processing Record 32 of Set 12 | joshimath
# Processing Record 33 of Set 12 | sambava
# Processing Record 34 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 35 of Set 12 | wakkanai
# Processing Record 36 of Set 12 | yuryevets
# Processing Record 37 of Set 12 | bereda
# Processing Record 38 of Set 12 | the valley
# Processing Record 39 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 40 of Set 12 | shipunovo
# Processing Record 41 of Set 12 | belogradcik
# City not found. Skipping...
# Processing Record 42 of Set 12 | aporawan
# City not found. Skipping...
# Processing Record 43 of Set 12 | kununurra
# Processing Record 44 of Set 12 | tual
# Processing Record 45 of Set 12 | lakatoro
# Processing Record 46 of Set 12 | pangani
# Processing Record 47 of Set 12 | zyryanka
# Processing Record 48 of Set 12 | oranjestad
# Processing Record 49 of Set 12 | nueva loja
# Processing Record 50 of Set 12 | minsk
# Processing Record 1 of Set 13 | mount gambier
# Processing Record 2 of Set 13 | pativilca
# Processing Record 3 of Set 13 | black river
# Processing Record 4 of Set 13 | nioro
# Processing Record 5 of Set 13 | howard springs
# Processing Record 6 of Set 13 | seymchan
# Processing Record 7 of Set 13 | pathein
# Processing Record 8 of Set 13 | terrace
# Processing Record 9 of Set 13 | sur
# Processing Record 10 of Set 13 | melfort
# Processing Record 11 of Set 13 | burica
# City not found. Skipping...
# Processing Record 12 of Set 13 | summerville
# Processing Record 13 of Set 13 | rio bueno
# Processing Record 14 of Set 13 | polunochnoye
# Processing Record 15 of Set 13 | asau
# Processing Record 16 of Set 13 | gigmoto
# Processing Record 17 of Set 13 | malchevskaya
# Processing Record 18 of Set 13 | belmonte
# Processing Record 19 of Set 13 | tezu
# Processing Record 20 of Set 13 | kars
# Processing Record 21 of Set 13 | arlit
# Processing Record 22 of Set 13 | sipoo
# Processing Record 23 of Set 13 | shestakovo
# Processing Record 24 of Set 13 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 25 of Set 13 | khandyga
# Processing Record 26 of Set 13 | ouadda
# Processing Record 27 of Set 13 | champerico
# Processing Record 28 of Set 13 | galesong
# Processing Record 29 of Set 13 | otane
# Processing Record 30 of Set 13 | murovani kurylivtsi
# Processing Record 31 of Set 13 | pilot butte
# Processing Record 32 of Set 13 | auch
# Processing Record 33 of Set 13 | manado
# Processing Record 34 of Set 13 | mahibadhoo
# Processing Record 35 of Set 13 | tekeli
# Processing Record 36 of Set 13 | la romana
# Processing Record 37 of Set 13 | mountain home
# Processing Record 38 of Set 13 | alihe
# Processing Record 39 of Set 13 | burriana
# Processing Record 40 of Set 13 | plettenberg bay
# Processing Record 41 of Set 13 | birao
# Processing Record 42 of Set 13 | kapit
# Processing Record 43 of Set 13 | lagoa vermelha
# Processing Record 44 of Set 13 | voh
# Processing Record 45 of Set 13 | santa vitoria do palmar
# Processing Record 46 of Set 13 | la rioja
# Processing Record 47 of Set 13 | lannion
# Processing Record 48 of Set 13 | demyanovo
# Processing Record 49 of Set 13 | sao joao da barra
# Processing Record 50 of Set 13 | pacific grove
# Processing Record 1 of Set 14 | bonthe
# Processing Record 2 of Set 14 | mecca
# Processing Record 3 of Set 14 | yumen
# Processing Record 4 of Set 14 | belize
# Processing Record 5 of Set 14 | itarema
# Processing Record 6 of Set 14 | krasnoselkup
# Processing Record 7 of Set 14 | marawi
# Processing Record 8 of Set 14 | kaman
# Processing Record 9 of Set 14 | farafangana
# Processing Record 10 of Set 14 | lundazi
# Processing Record 11 of Set 14 | swift current
# Processing Record 12 of Set 14 | bathsheba
# Processing Record 13 of Set 14 | yunjinghong
# City not found. Skipping...
# Processing Record 14 of Set 14 | quelimane
# Processing Record 15 of Set 14 | paciran
# Processing Record 16 of Set 14 | maniitsoq
# Processing Record 17 of Set 14 | paamiut
# Processing Record 18 of Set 14 | zemaiciu naumiestis
# Processing Record 19 of Set 14 | darnah
# Processing Record 20 of Set 14 | tilichiki
# Processing Record 21 of Set 14 | saint-louis
# Processing Record 22 of Set 14 | mount barker
# Processing Record 23 of Set 14 | takoradi
# Processing Record 24 of Set 14 | matay
# Processing Record 25 of Set 14 | cairns
# Processing Record 26 of Set 14 | quatre cocos
# Processing Record 27 of Set 14 | kabompo
# Processing Record 28 of Set 14 | homer
# Processing Record 29 of Set 14 | awbari
# Processing Record 30 of Set 14 | omsukchan
# Processing Record 31 of Set 14 | sedelnikovo
# City not found. Skipping...
# Processing Record 32 of Set 14 | hirara
# Processing Record 33 of Set 14 | avera
# Processing Record 34 of Set 14 | acapulco
# Processing Record 35 of Set 14 | tashtyp
# Processing Record 36 of Set 14 | yurla
# Processing Record 37 of Set 14 | noumea
# Processing Record 38 of Set 14 | kimbe
# Processing Record 39 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 14 | alanya
# Processing Record 41 of Set 14 | broome
# Processing Record 42 of Set 14 | camana
# Processing Record 43 of Set 14 | namtsy
# Processing Record 44 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 45 of Set 14 | sao jose da coroa grande
# Processing Record 46 of Set 14 | miranorte
# City not found. Skipping...
# Processing Record 47 of Set 14 | state college
# Processing Record 48 of Set 14 | vaitape
# Processing Record 49 of Set 14 | sombrio
# Processing Record 50 of Set 14 | smithers
# Processing Record 1 of Set 15 | qasigiannguit
# Processing Record 2 of Set 15 | xining
# Processing Record 3 of Set 15 | yerbogachen
# Processing Record 4 of Set 15 | korla
# Processing Record 5 of Set 15 | kalinovskoye
# Processing Record 6 of Set 15 | sainte-rose
# Processing Record 7 of Set 15 | arman
# Processing Record 8 of Set 15 | rincon
# Processing Record 9 of Set 15 | verkhnyaya toyma
# Processing Record 10 of Set 15 | sa kaeo
# Processing Record 11 of Set 15 | pekan
# Processing Record 12 of Set 15 | praia
# Processing Record 13 of Set 15 | constitucion
# Processing Record 14 of Set 15 | portales
# Processing Record 15 of Set 15 | mandalgovi
# Processing Record 16 of Set 15 | tivaouane
# Processing Record 17 of Set 15 | ciudad bolivar
# Processing Record 18 of Set 15 | gari
# Processing Record 19 of Set 15 | baruun-urt
# Processing Record 20 of Set 15 | lengshuijiang
# Processing Record 21 of Set 15 | boa vista
# Processing Record 22 of Set 15 | sao miguel do araguaia
# Processing Record 23 of Set 15 | padang
# Processing Record 24 of Set 15 | yangambi
# Processing Record 25 of Set 15 | skjervoy
# Processing Record 26 of Set 15 | tsogni
# Processing Record 27 of Set 15 | beringovskiy
# Processing Record 28 of Set 15 | khorixas
# Processing Record 29 of Set 15 | balkanabat
# Processing Record 30 of Set 15 | udachnyy
# Processing Record 31 of Set 15 | izumo
# Processing Record 32 of Set 15 | kosa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Get the length of the data
len(city_data)
# Out:
# 671

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Aqtobe  50.2797   57.2072     50.09        76          75
# 1            Hilo  19.7297 -155.0900     76.73        84         100
# 2        Portland  45.5234 -122.6762     56.61        50          75
# 3       Wonthaggi -38.6044  145.5913     67.82        74          30
# 4        Westport  41.1415  -73.3579     55.89        62          20
# 5       Key Largo  25.0865  -80.4473     77.00        50          93
# 6        Khatanga  71.9667  102.5000     -5.28       100          93
# 7           Ancud -41.8697  -73.8203     47.23        82         100
# 8         Mataura -46.1927  168.8643     57.11        61          33
# 9  Vestmannaeyjar  63.4427  -20.2734     39.22        67         100
#
#    Wind Speed Current Description Country                 Date
# 0        8.95       broken clouds      KZ  2022-04-09 22:40:19
# 1       11.50     overcast clouds      US  2022-04-09 22:37:58
# 2       13.80       broken clouds      US  2022-04-09 22:40:19
# 3       11.32    scattered clouds      AU  2022-04-09 22:40:20
# 4       13.80          light rain      US  2022-04-09 22:40:20
# 5       20.87     overcast clouds      US  2022-04-09 22:40:21
# 6        2.35     overcast clouds      RU  2022-04-09 22:40:21
# 7        7.90          light rain      CL  2022-04-09 22:40:21
# 8        4.92    scattered clouds      NZ  2022-04-09 22:40:21
# 9       27.98     overcast clouds      IS  2022-04-09 22:40:22

# %%
#Reorder the DF columns
new_column_order = ["City","Country", "Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed", "Current Description"]

# Rearrange the column order in the DF
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Aqtobe      KZ  50.2797   57.2072     50.09        76          75
# 1            Hilo      US  19.7297 -155.0900     76.73        84         100
# 2        Portland      US  45.5234 -122.6762     56.61        50          75
# 3       Wonthaggi      AU -38.6044  145.5913     67.82        74          30
# 4        Westport      US  41.1415  -73.3579     55.89        62          20
# 5       Key Largo      US  25.0865  -80.4473     77.00        50          93
# 6        Khatanga      RU  71.9667  102.5000     -5.28       100          93
# 7           Ancud      CL -41.8697  -73.8203     47.23        82         100
# 8         Mataura      NZ -46.1927  168.8643     57.11        61          33
# 9  Vestmannaeyjar      IS  63.4427  -20.2734     39.22        67         100
#
#    Wind Speed Current Description
# 0        8.95       broken clouds
# 1       11.50     overcast clouds
# 2       13.80       broken clouds
# 3       11.32    scattered clouds
# 4       13.80          light rain
# 5       20.87     overcast clouds
# 6        2.35     overcast clouds
# 7        7.90          light rain
# 8        4.92    scattered clouds
# 9       27.98     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
